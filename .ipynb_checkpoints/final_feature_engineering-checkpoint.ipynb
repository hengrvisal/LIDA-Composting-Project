# %%
import os
import pandas as pd

# %%
df = pd.read_csv('synthetic_compost_data.csv')
df.head()
# Out:
#    time_stamp  moisture_active1  moisture_active2     oxygen  lid       co2  \
# 0  2024-01-01         53.414959         54.445332  14.585502    1  5.155804
# 1  2024-01-02         54.431544         55.309214  14.804655    1  5.425923
# 2  2024-01-03         55.332008         55.207526  15.543138    1  4.899575
# 3  2024-01-04         55.714561         56.200347  15.559422    1  5.018819
# 4  2024-01-05         51.243475         51.566163  15.328532    1  5.071450
#
#   device_id  temperature_active1  temperature_active2  temperature_active3  \
# 0      dev1            30.745071            29.792604            30.971533
# 1      dev1            33.870992            33.871017            36.591041
# 2      dev1            37.740233            39.258285            37.749318
# 3      dev1            43.029610            39.796746            40.079290
# 4      dev1            45.369642            47.360260            45.526853
#
# ...

# %%
df = pd.read_csv('lida_tabletrimmed.csv')
df.head()
# Out:
#    moisture_active1  moisture_active2     oxygen   lid   co2  \
# 0                14                15  10.429501  open  6473
# 1                15                17  11.406513  open  6429
# 2                 7                15  11.895020  open  6446
# 3                15                16  12.207036  open  6410
# 4                14                16  12.386153  open  6703
#
#          time_stamp device_id  temperature_curing1  temperature_curing2  \
# 0  28/06/2024 18:03    YJWCHg                    0                    0
# 1  28/06/2024 18:03    YJWCHg                    0                    0
# 2  28/06/2024 18:03    YJWCHg                    0                    0
# 3  28/06/2024 18:03    YJWCHg                    0                    0
# 4  28/06/2024 18:03    YJWCHg                    0                    0
#
#    moisture_curing1  moisture_curing2  automation_active  methane  \
# 0               134                14              False      965
# ...
